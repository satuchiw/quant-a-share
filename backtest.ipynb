# %%
import import_ipynb
from readdata import *
from strategy import Strategy_MA
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
import backtrader as bt
import math
# %matplotlib widget
# %matplotlib inline

def import_data_from_csv(file_path):
    # 读取现有数据

    columns = ['date','open','close','high', 'low', 'volume'] # 对于backtrader来说只需要这几列数据（还有openinterest暂时先不用）
    data = pd.read_csv(file_path, usecols=columns, parse_dates=True, index_col='date')
    data = data.sort_index()
    
    return data
    
class Strategy_MA(bt.Strategy):
    # 均线策略
    params = (
                ('ma5_period', 5),
                ('ma20_period', 20) 
    )  # 设定全局交易策略参数

    def log(self, txt, dt=None):
        # 日志记录函数
        dt = dt or self.datas[0].datetime.date(0)
        print('date:%s, %s' % (dt.isoformat(), txt))
    
    def __init__(self):
        # 初始化交易指令、买卖价格和手续费
        self.order = None
        self.buyprice = None
        self.buycomm = None 
 
        # 添加移动均线指标，内置了talib模块
        self.ma5 = bt.indicators.SimpleMovingAverage(
            self.data.close, period=self.params.ma5_period)
        self.ma20 = bt.indicators.SimpleMovingAverage(
            self.data.close, period=self.params.ma20_period)
        
    def notify_order(self, order):
        # 处理和打印订单信息
        
        # 买卖订单已提交/已接受 - 无需操作
        if order.status in [order.Submitted, order.Accepted]:
            return
        
        # 检查订单是否已完成
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log('买入已执行，%.2f' % order.executed.price) # 记录日志
            elif order.issell():
                self.log('卖出已执行，%.2f' % order.executed.price)
                
            self.bar_executed = len(self)
            
        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('订单已取消/保证金不足/拒绝')
            
        # 记录：没有待处理订单
        self.order = None
        
    def notify_trade(self, trade):
        # 处理和打印交易信息
        if not trade.isclosed:
            return

        self.log(f'本次交易毛利润：{trade.pnl:.2f},扣除交易费用后的净利润：{trade.pnlcomm:.2f}')

        if trade.pnlcomm > 0:  # 如果净收益大于0，就认为这次交易盈利，否则认为这次交易亏损（同时输出交易编号）
            self.log(f'交易获利： {trade.ref}')
        else:
            self.log(f'交易亏损： {trade.ref}')  

    def next(self):
        #主要的循环策略执行部分
        
        # 当前资产总价`
        total_value = self.broker.getvalue()
        
        # 检查是否有待处理订单，如果有就不执行此轮操作
        if self.order:
            return
        
        # 回测最后一天停止交易
        if self.datas[0].datetime.date(0) == end:
            return 
        
        # 这里是九成仓买入卖出的策略
        if self.position.size:  # 检查当前是否已持仓（因为该策略只有持仓和空仓两种状态）
            if self.ma5[0] < self.ma20[0] and self.ma5[-1] > self.ma20[-1]:   # 检查是否满足卖出条件
                self.log("总资产价格：%.2f元" % total_value) 
                print("{:-^50s}".format("Split Line"))
                self.log('卖出创建，%.2f' % self.data.close[0])
                self.close()
        elif self.ma5[0] > self.ma20[0] and self.ma5[-1] < self.ma20[-1]:     # 检查是否满足买入条件(此处是否应当用第二天买入价？)
            order_amount = abs((total_value*0.9/self.datas[0].close[0])//100*100)
            self.log("总资产价格：%.2f元" % total_value)
            print("{:-^50s}".format("Split Line"))
            self.log('买入创建，%.2f' % self.data.close[0])
            self.buy(self.datas[0], size=order_amount)

def run_backtest(strategy, data, startcash, start, end):
    # 执行回测
    # 实例化Cerebro回测引擎
    cerebro = bt.Cerebro()
    # 添加策略分析指标
    cerebro.addanalyzer(bt.analyzers.TradeAnalyzer, _name='tradeanalyzer') # 平仓交易信息
    cerebro.addanalyzer(bt.analyzers.AnnualReturn, _name='annualReturn') # 年度回报
    cerebro.addanalyzer(bt.analyzers.DrawDown, _name='drawdown') # 回撤
    cerebro.addanalyzer(bt.analyzers.SharpeRatio, _name='sharpe') # 夏普率
    # 添加数据
    cerebro.adddata(bt.feeds.PandasData(dataname=data,fromdate=start,todate=end))
    # 添加策略
    cerebro.addstrategy(strategy)
    # 设置初始投资总额
    cerebro.broker.setcash(startcash)
    # 设置交易佣金（双边万五）
    cerebro.broker.setcommission(commission=0.0005)
    # 添加观测器
    # cerebro.addobserver(...)
    # 运行回测
    results = cerebro.run()
    
    # 打印分析器输出结果（这样输出很乱，暂时不执行）
    #print('Tradeanalyzer:', results[0].analyzers.tradeanalyzer.get_analysis())
    #print('AnnualReturn:', results[0].analyzers.annualReturn.get_analysis())
    #print('DrawDown:', results[0].analyzers.drawdown.get_analysis())
    #print('SharpeRatio:', results[0].analyzers.sharpe.get_analysis())
    
    return cerebro, results
def evaluate_results(cerebro, results):
    # 交易分析与评价
    
    #获取回测结束后的总资金
    portvalue = cerebro.broker.getvalue()
    pnl = portvalue - startcash
    #打印结果
    print(f'总资金: {round(portvalue,2)}')
    # 净收益
    print(f'净收益: {round(pnl,2)}')
    
def plot_results(cerebro):
    # 交易过程可视化
    
    cerebro.plot(style='candlestick')
def analyze_backtest(cerebro, results):
    """全面分析回测结果"""
    # 获取策略实例
    strat = results[0]
    
    # 打印基本账户信息
    start_val = cerebro.broker.startingcash
    end_val = cerebro.broker.getvalue()
    print(f"初始资金: ¥{start_val:,.2f}")
    print(f"最终资金: ¥{end_val:,.2f}")
    print(f"净收益: ¥{end_val - start_val:,.2f} ({((end_val/start_val)-1)*100:.2f}%)")
    
    # 分析交易统计
    ta = strat.analyzers.tradeanalyzer.get_analysis()
    print("\n===== 交易统计 =====")
    print(f"总交易次数: {ta.total.closed}")
    print(f"盈利交易: {ta.won.total} ({ta.won.total/ta.total.closed*100:.2f}%)")
    print(f"亏损交易: {ta.lost.total} ({ta.lost.total/ta.total.closed*100:.2f}%)")
    print(f"平均盈利: ¥{ta.won.pnl.average:.2f}")
    print(f"平均亏损: ¥{ta.lost.pnl.average:.2f}")
    
    # 分析风险指标
    dd = strat.analyzers.drawdown.get_analysis()
    print("\n===== 风险分析 =====")
    print(f"最大回撤: {dd.max.drawdown:.2f}%")
    print(f"最长回撤周期: {dd.max.len} 天")
    
    # 夏普比率
    sharpe = strat.analyzers.sharpe.get_analysis()
    print(f"年化夏普比率: {sharpe['sharperatio']:.2f}")
    
    # 年度回报
    annual_ret = strat.analyzers.annualReturn.get_analysis()
    print("\n===== 年度回报 =====")
    for year, ret in annual_ret.items():
        print(f"{year}: {ret*100:.2f}%")
    
    # 绘制资金曲线
    plt.figure(figsize=(12, 6))
    plt.plot(strat.equity.array)
    plt.title('资金曲线')
    plt.xlabel('交易日')
    plt.ylabel('账户价值')
    plt.grid(True)
    plt.show()
    
    return {
        'starting_cash': start_val,
        'ending_cash': end_val,
        'total_trades': ta.total.closed,
        'win_rate': ta.won.total/ta.total.closed,
        'max_drawdown': dd.max.drawdown,
        'sharpe_ratio': sharpe['sharperatio']
    }

# %%
if __name__ == '__main__':
    '''
    以2012年11月30日起贵州茅台10年的股价数据为例，执行双均线策略，起始资金10万元
    '''

    start_date = '2012-11-20'
    end_date = '2022-11-20'
    start = '2012-11-20'
    end = '2022-11-20'
    start = datetime.strptime(start, '%Y-%m-%d')
    end = datetime.strptime(end, '%Y-%m-%d')  
    # 转换为datetime对象（用于Backtrader）
    # start='2012-11-20'
    # end='2022-11-20'
    startcash = 100000.0
    freq='d'
    code = "sz.000538"
    login_baostock()
        # 获取股票基本数据
    start_str=str(start_date)
    end_str=str(end_date)
    rs1 = marketinfo(code, start_str, end_str, frequency=freq)
    rs = get_result(rs1)
    # print(rs)

    # 创建数据框并确保所有列都是数值类型
    data = rs[['date', 'open', 'close', 'high', 'low', 'volume']].copy()
    
    # 将价格和交易量列转换为浮点数
    numeric_columns = ['open', 'close', 'high', 'low', 'volume']
    for col in numeric_columns:
        data[col] = data[col].astype(float)
    
    data['date'] = pd.to_datetime(data['date'])
    data = data.set_index('date')
    logout_baostock()

    cerebro, results = run_backtest(Strategy_MA, data, startcash, start, end)
    
    print(f"初始资金: {startcash}\n回测期间：{start.strftime('%Y%m%d')}:{end.strftime('%Y%m%d')}")
    
    evaluate_results(cerebro, results)
# Out:
# login success!
# login respond error_code:0
# login respond error_msg:success
# query_history_k_data_plus respond error_code:0
# query_history_k_data_plus respond error_msg:success
# logout success!
# date:2012-12-20, 总资产价格：100000.00元
# --------------------Split Line--------------------
# date:2012-12-20, 买入创建，63.60
# date:2012-12-21, 买入已执行，63.65
# date:2013-03-01, 总资产价格：118561.45元
# --------------------Split Line--------------------
# date:2013-03-01, 卖出创建，76.94
# date:2013-03-04, 卖出已执行，77.90
# date:2013-03-04, 本次交易毛利润：19950.00,扣除交易费用后的净利润：19850.92
# date:2013-03-04, 交易获利： 293
# date:2013-03-05, 总资产价格：119850.92元
# --------------------Split Line--------------------
# date:2013-03-05, 买入创建，79.76
# date:2013-03-06, 买入已执行，79.75
# date:2013-03-13, 总资产价格：113910.08元
# --------------------Split Line--------------------
# date:2013-03-13, 卖出创建，75.22
# date:2013-03-14, 卖出已执行，74.55
# date:2013-03-14, 本次交易毛利润：-6760.00,扣除交易费用后的净利润：-6860.30
# date:2013-03-14, 交易亏损： 294
# date:2013-03-19, 总资产价格：112990.62元
# --------------------Split Line--------------------
# date:2013-03-19, 买入创建，78.52
# date:2013-03-20, 买入已执行，78.53
# date:2013-04-10, 总资产价格：116507.50元
# --------------------Split Line--------------------
# date:2013-04-10, 卖出创建，81.50
# date:2013-04-11, 卖出已执行，81.50
# date:2013-04-11, 本次交易毛利润：3564.00,扣除交易费用后的净利润：3467.98
# date:2013-04-11, 交易获利： 295
# date:2013-04-19, 总资产价格：116458.60元
# --------------------Split Line--------------------
# date:2013-04-19, 买入创建，85.45
# date:2013-04-22, 买入已执行，88.50
# date:2013-05-21, 总资产价格：112205.50元
# --------------------Split Line--------------------
# date:2013-05-21, 卖出创建，85.00
# date:2013-05-22, 卖出已执行，85.49
# date:2013-05-22, 本次交易毛利润：-3612.00,扣除交易费用后的净利润：-3716.39
# date:2013-05-22, 交易亏损： 296
# date:2013-05-28, 总资产价格：112742.21元
# --------------------Split Line--------------------
# date:2013-05-28, 买入创建，89.50
# date:2013-05-29, 买入已执行，89.95
# date:2013-06-06, 总资产价格：109315.74元
# --------------------Split Line--------------------
# date:2013-06-06, 卖出创建，86.88
# date:2013-06-07, 卖出已执行，87.00
# date:2013-06-07, 本次交易毛利润：-3245.00,扣除交易费用后的净利润：-3342.32
# date:2013-06-07, 交易亏损： 297
# date:2013-07-02, 总资产价格：109399.89元
# --------------------Split Line--------------------
# date:2013-07-02, 买入创建，93.99
# date:2013-07-03, 买入已执行，93.60
# date:2013-08-13, 总资产价格：117503.09元
# --------------------Split Line--------------------
# date:2013-08-13, 卖出创建，101.75
# date:2013-08-14, 卖出已执行，101.35
# date:2013-08-14, 本次交易毛利润：7750.00,扣除交易费用后的净利润：7652.52
# date:2013-08-14, 交易获利： 298
# date:2013-08-26, 总资产价格：117052.41元
# --------------------Split Line--------------------
# date:2013-08-26, 买入创建，107.61
# date:2013-08-27, 买入已执行，107.32
# date:2013-09-13, 总资产价格：114169.12元
# --------------------Split Line--------------------
# date:2013-09-13, 卖出创建，104.17
# date:2013-09-16, 卖出已执行，104.98
# date:2013-09-16, 本次交易毛利润：-2106.00,扣除交易费用后的净利润：-2201.53
# date:2013-09-16, 交易亏损： 299
# date:2013-09-23, 总资产价格：114850.88元
# --------------------Split Line--------------------
# date:2013-09-23, 买入创建，114.40
# date:2013-09-24, 买入已执行，113.08
# date:2013-10-23, 总资产价格：112027.99元
# --------------------Split Line--------------------
# date:2013-10-23, 卖出创建，110.00
# date:2013-10-24, 卖出已执行，110.00
# date:2013-10-24, 本次交易毛利润：-2772.00,扣除交易费用后的净利润：-2872.39
# date:2013-10-24, 交易亏损： 300
# date:2013-11-28, 总资产价格：111978.49元
# --------------------Split Line--------------------
# date:2013-11-28, 买入创建，102.18
# date:2013-11-29, 买入已执行，102.01
# date:2013-12-16, 总资产价格：108683.59元
# --------------------Split Line--------------------
# date:2013-12-16, 卖出创建，98.40
# date:2013-12-17, 卖出已执行，98.40
# date:2013-12-17, 本次交易毛利润：-3249.00,扣除交易费用后的净利润：-3339.18
# date:2013-12-17, 交易亏损： 301
# date:2013-12-31, 总资产价格：108639.31元
# --------------------Split Line--------------------
# date:2013-12-31, 买入创建，101.99
# date:2014-01-02, 买入已执行，101.97
# date:2014-01-10, 总资产价格：104966.42元
# --------------------Split Line--------------------
# date:2014-01-10, 卖出创建，97.94
# date:2014-01-13, 卖出已执行，97.94
# date:2014-01-13, 本次交易毛利润：-3627.00,扣除交易费用后的净利润：-3716.96
# date:2014-01-13, 交易亏损： 302
# date:2014-03-12, 总资产价格：104922.35元
# --------------------Split Line--------------------
# date:2014-03-12, 买入创建，87.82
# date:2014-03-13, 买入已执行，87.80
# date:2014-03-20, 总资产价格：99348.45元
# --------------------Split Line--------------------
# date:2014-03-20, 卖出创建，82.27
# date:2014-03-21, 卖出已执行，81.20
# date:2014-03-21, 本次交易毛利润：-6600.00,扣除交易费用后的净利润：-6684.50
# date:2014-03-21, 交易亏损： 303
# date:2014-04-11, 总资产价格：98237.85元
# --------------------Split Line--------------------
# date:2014-04-11, 买入创建，87.76
# date:2014-04-14, 买入已执行，87.78
# date:2014-04-29, 总资产价格：93073.96元
# --------------------Split Line--------------------
# date:2014-04-29, 卖出创建，82.66
# date:2014-04-30, 卖出已执行，86.00
# date:2014-04-30, 本次交易毛利润：-1780.00,扣除交易费用后的净利润：-1866.89
# date:2014-04-30, 交易亏损： 304
# date:2014-05-07, 总资产价格：96370.96元
# --------------------Split Line--------------------
# date:2014-05-07, 买入创建，87.05
# date:2014-05-08, 买入已执行，86.85
# date:2014-05-22, 总资产价格：96601.87元
# --------------------Split Line--------------------
# date:2014-05-22, 卖出创建，87.15
# date:2014-05-23, 卖出已执行，87.01
# date:2014-05-23, 本次交易毛利润：144.00,扣除交易费用后的净利润：65.76
# date:2014-05-23, 交易获利： 305
# date:2014-05-27, 总资产价格：96436.72元
# --------------------Split Line--------------------
# date:2014-05-27, 买入创建，87.32
# date:2014-05-28, 买入已执行，57.53
# date:2014-05-28, 总资产价格：96797.83元
# --------------------Split Line--------------------
# date:2014-05-28, 卖出创建，57.96
# date:2014-05-29, 卖出已执行，58.25
# date:2014-05-29, 本次交易毛利润：648.00,扣除交易费用后的净利润：595.90
# date:2014-05-29, 交易获利： 306
# date:2014-07-22, 总资产价格：97032.62元
# --------------------Split Line--------------------
# date:2014-07-22, 买入创建，51.91
# date:2014-07-23, 买入已执行，51.88
# date:2014-08-15, 总资产价格：99711.11元
# --------------------Split Line--------------------
# date:2014-08-15, 卖出创建，53.58
# date:2014-08-18, 卖出已执行，53.55
# date:2014-08-18, 本次交易毛利润：2672.00,扣除交易费用后的净利润：2587.66
# date:2014-08-18, 交易获利： 307
# date:2014-09-10, 总资产价格：99620.27元
# --------------------Split Line--------------------
# date:2014-09-10, 买入创建，51.80
# date:2014-09-11, 买入已执行，51.80
# date:2014-09-16, 总资产价格：97281.24元
# --------------------Split Line--------------------
# date:2014-09-16, 卖出创建，50.45
# date:2014-09-17, 卖出已执行，50.60
# date:2014-09-17, 本次交易毛利润：-2040.00,扣除交易费用后的净利润：-2127.04
# date:2014-09-17, 交易亏损： 308
# date:2014-09-23, 总资产价格：97493.23元
# --------------------Split Line--------------------
# date:2014-09-23, 买入创建，51.45
# date:2014-09-24, 买入已执行，51.31
# date:2014-09-30, 总资产价格：97381.62元
# --------------------Split Line--------------------
# date:2014-09-30, 卖出创建，51.27
# date:2014-10-08, 卖出已执行，51.40
# date:2014-10-08, 本次交易毛利润：153.00,扣除交易费用后的净利润：65.70
# date:2014-10-08, 交易获利： 309
# date:2014-10-08, 总资产价格：97558.93元
# --------------------Split Line--------------------
# date:2014-10-08, 买入创建，56.40
# date:2014-10-09, 买入已执行，57.00
# date:2014-10-27, 总资产价格：91696.18元
# --------------------Split Line--------------------
# date:2014-10-27, 卖出创建，53.12
# date:2014-10-28, 卖出已执行，53.30
# date:2014-10-28, 本次交易毛利润：-5550.00,扣除交易费用后的净利润：-5632.73
# date:2014-10-28, 交易亏损： 310
# date:2014-11-14, 总资产价格：91926.20元
# --------------------Split Line--------------------
# date:2014-11-14, 买入创建，55.16
# date:2014-11-17, 买入已执行，55.55
# date:2014-12-23, 总资产价格：96437.32元
# --------------------Split Line--------------------
# date:2014-12-23, 卖出创建，58.80
# date:2014-12-24, 卖出已执行，58.80
# date:2014-12-24, 本次交易毛利润：4550.00,扣除交易费用后的净利润：4469.95
# date:2014-12-24, 交易获利： 311
# date:2014-12-31, 总资产价格：96396.16元
# --------------------Split Line--------------------
# date:2014-12-31, 买入创建，63.15
# date:2015-01-05, 买入已执行，63.17
# date:2015-01-29, 总资产价格：96004.10元
# --------------------Split Line--------------------
# date:2015-01-29, 卖出创建，62.90
# date:2015-01-30, 卖出已执行，63.38
# date:2015-01-30, 本次交易毛利润：273.00,扣除交易费用后的净利润：190.74
# date:2015-01-30, 交易获利： 312
# date:2015-03-02, 总资产价格：96586.90元
# --------------------Split Line--------------------
# date:2015-03-02, 买入创建，62.57
# date:2015-03-03, 买入已执行，62.58
# date:2015-05-04, 总资产价格：103982.23元
# --------------------Split Line--------------------
# date:2015-05-04, 卖出创建，68.30
# date:2015-05-05, 卖出已执行，68.40
# date:2015-05-05, 本次交易毛利润：7566.00,扣除交易费用后的净利润：7480.86
# date:2015-05-05, 交易获利： 313
# date:2015-05-22, 总资产价格：104067.77元
# --------------------Split Line--------------------
# date:2015-05-22, 买入创建，71.46
# date:2015-05-25, 买入已执行，71.29
# date:2015-07-03, 总资产价格：108844.43元
# --------------------Split Line--------------------
# date:2015-07-03, 卖出创建，75.00
# date:2015-07-06, 卖出已执行，82.00
# date:2015-07-06, 本次交易毛利润：13923.00,扣除交易费用后的净利润：13823.36
# date:2015-07-06, 交易获利： 314
# date:2015-07-29, 总资产价格：117891.13元
# --------------------Split Line--------------------
# date:2015-07-29, 买入创建，73.80
# date:2015-07-30, 买入已执行，73.50
# date:2015-07-31, 总资产价格：117937.68元
# --------------------Split Line--------------------
# date:2015-07-31, 卖出创建，73.57
# date:2015-08-03, 卖出已执行，72.58
# date:2015-08-03, 本次交易毛利润：-1288.00,扣除交易费用后的净利润：-1390.26
# date:2015-08-03, 交易亏损： 315
# date:2015-08-03, 总资产价格：116500.87元
# --------------------Split Line--------------------
# date:2015-08-03, 买入创建，75.18
# date:2015-08-04, 买入已执行，75.10
# date:2015-08-18, 总资产价格：111317.06元
# --------------------Split Line--------------------
# date:2015-08-18, 卖出创建，71.15
# date:2015-08-19, 卖出已执行，70.10
# date:2015-08-19, 本次交易毛利润：-6500.00,扣除交易费用后的净利润：-6594.38
# date:2015-08-19, 交易亏损： 316
# date:2015-09-14, 总资产价格：109906.49元
# --------------------Split Line--------------------
# date:2015-09-14, 买入创建，68.19
# date:2015-09-15, 买入已执行，67.51
# date:2015-09-17, 总资产价格：109145.23元
# --------------------Split Line--------------------
# date:2015-09-17, 卖出创建，67.00
# date:2015-09-18, 卖出已执行，67.00
# date:2015-09-18, 本次交易毛利润：-714.00,扣除交易费用后的净利润：-808.16
# date:2015-09-18, 交易亏损： 317
# date:2015-09-22, 总资产价格：109098.33元
# --------------------Split Line--------------------
# date:2015-09-22, 买入创建，68.01
# date:2015-09-23, 买入已执行，67.55
# date:2015-09-23, 总资产价格：108701.05元
# --------------------Split Line--------------------
# date:2015-09-23, 卖出创建，67.30
# date:2015-09-24, 卖出已执行，67.30
# date:2015-09-24, 本次交易毛利润：-350.00,扣除交易费用后的净利润：-444.39
# date:2015-09-24, 交易亏损： 318
# date:2015-10-14, 总资产价格：108653.94元
# --------------------Split Line--------------------
# date:2015-10-14, 买入创建，67.70
# date:2015-10-15, 买入已执行，67.50
# date:2015-11-03, 总资产价格：106590.69元
# --------------------Split Line--------------------
# date:2015-11-03, 卖出创建，66.06
# date:2015-11-04, 卖出已执行，66.25
# date:2015-11-04, 本次交易毛利润：-1750.00,扣除交易费用后的净利润：-1843.62
# date:2015-11-04, 交易亏损： 319
# date:2015-11-06, 总资产价格：106810.31元
# --------------------Split Line--------------------
# date:2015-11-06, 买入创建，69.52
# date:2015-11-09, 买入已执行，70.00
# date:2015-11-30, 总资产价格：103748.81元
# --------------------Split Line--------------------
# date:2015-11-30, 卖出创建，67.68
# date:2015-12-01, 卖出已执行，67.68
# date:2015-12-01, 本次交易毛利润：-3016.00,扣除交易费用后的净利润：-3105.49
# date:2015-12-01, 交易亏损： 320
# date:2015-12-08, 总资产价格：103704.82元
# --------------------Split Line--------------------
# date:2015-12-08, 买入创建，72.46
# date:2015-12-09, 买入已执行，72.38
# date:2016-01-04, 总资产价格：98249.39元
# --------------------Split Line--------------------
# date:2016-01-04, 卖出创建，67.87
# date:2016-01-05, 卖出已执行，67.88
# date:2016-01-05, 本次交易毛利润：-5400.00,扣除交易费用后的净利润：-5484.16
# date:2016-01-05, 交易亏损： 321
# date:2016-02-15, 总资产价格：98220.67元
# --------------------Split Line--------------------
# date:2016-02-15, 买入创建，59.98
# date:2016-02-16, 买入已执行，60.31
# date:2016-02-25, 总资产价格：93544.45元
# --------------------Split Line--------------------
# date:2016-02-25, 卖出创建，57.00
# date:2016-02-26, 卖出已执行，57.11
# date:2016-02-26, 本次交易毛利润：-4480.00,扣除交易费用后的净利润：-4562.19
# date:2016-02-26, 交易亏损： 322
# date:2016-03-16, 总资产价格：93658.47元
# --------------------Split Line--------------------
# date:2016-03-16, 买入创建，59.50
# date:2016-03-17, 买入已执行，59.42
# date:2016-04-21, 总资产价格：93924.88元
# --------------------Split Line--------------------
# date:2016-04-21, 卖出创建，59.64
# date:2016-04-22, 卖出已执行，59.35
# date:2016-04-22, 本次交易毛利润：-98.00,扣除交易费用后的净利润：-181.14
# date:2016-04-22, 交易亏损： 323
# date:2016-05-05, 总资产价格：93477.33元
# --------------------Split Line--------------------
# date:2016-05-05, 买入创建，61.80
# date:2016-05-06, 买入已执行，61.51
# date:2016-05-11, 总资产价格：93307.35元
# --------------------Split Line--------------------
# date:2016-05-11, 卖出创建，61.41
# date:2016-05-12, 卖出已执行，60.80
# date:2016-05-12, 本次交易毛利润：-923.00,扣除交易费用后的净利润：-1002.50
# date:2016-05-12, 交易亏损： 324
# date:2016-05-13, 总资产价格：92474.83元
# --------------------Split Line--------------------
# date:2016-05-13, 买入创建，61.88
# date:2016-05-16, 买入已执行，61.51
# date:2016-05-27, 总资产价格：92252.85元
# --------------------Split Line--------------------
# date:2016-05-27, 卖出创建，61.37
# date:2016-05-30, 卖出已执行，61.40
# date:2016-05-30, 本次交易毛利润：-143.00,扣除交易费用后的净利润：-222.89
# date:2016-05-30, 交易亏损： 325
# date:2016-06-01, 总资产价格：92251.94元
# --------------------Split Line--------------------
# date:2016-06-01, 买入创建，62.20
# date:2016-06-02, 买入已执行，62.16
# date:2016-06-17, 总资产价格：91847.54元
# --------------------Split Line--------------------
# date:2016-06-17, 卖出创建，61.88
# date:2016-06-20, 卖出已执行，61.80
# date:2016-06-20, 本次交易毛利润：-468.00,扣除交易费用后的净利润：-548.57
# date:2016-06-20, 交易亏损： 326
# date:2016-06-28, 总资产价格：91703.37元
# --------------------Split Line--------------------
# date:2016-06-28, 买入创建，64.22
# date:2016-06-29, 买入已执行，64.35
# date:2016-08-03, 总资产价格：97520.76元
# --------------------Split Line--------------------
# date:2016-08-03, 卖出创建，69.23
# date:2016-08-04, 卖出已执行，69.23
# date:2016-08-04, 本次交易毛利润：5856.00,扣除交易费用后的净利润：5775.85
# date:2016-08-04, 交易获利： 327
# date:2017-03-16, 总资产价格：97479.22元
# --------------------Split Line--------------------
# date:2017-03-16, 买入创建，78.14
# date:2017-03-17, 买入已执行，78.15
# date:2017-04-14, 总资产价格：104289.24元
# --------------------Split Line--------------------
# date:2017-04-14, 卖出创建，84.38
# date:2017-04-17, 卖出已执行，84.39
# date:2017-04-17, 本次交易毛利润：6864.00,扣除交易费用后的净利润：6774.60
# date:2017-04-17, 交易获利： 328
# date:2017-04-20, 总资产价格：104253.82元
# --------------------Split Line--------------------
# date:2017-04-20, 买入创建，91.35
# date:2017-04-21, 买入已执行，91.30
# date:2017-05-05, 总资产价格：96208.17元
# --------------------Split Line--------------------
# date:2017-05-05, 卖出创建，83.30
# date:2017-05-08, 卖出已执行，83.15
# date:2017-05-08, 本次交易毛利润：-8150.00,扣除交易费用后的净利润：-8237.22
# date:2017-05-08, 交易亏损： 329
# date:2017-05-16, 总资产价格：96016.60元
# --------------------Split Line--------------------
# date:2017-05-16, 买入创建，88.78
# date:2017-05-17, 买入已执行，88.80
# date:2017-07-03, 总资产价格：98145.64元
# --------------------Split Line--------------------
# date:2017-07-03, 卖出创建，91.21
# date:2017-07-04, 卖出已执行，91.12
# date:2017-07-04, 本次交易毛利润：2088.00,扣除交易费用后的净利润：2007.04
# date:2017-07-04, 交易获利： 330
# date:2017-08-14, 总资产价格：98023.63元
# --------------------Split Line--------------------
# date:2017-08-14, 买入创建，90.68
# date:2017-08-15, 买入已执行，90.68
# date:2017-08-31, 总资产价格：94670.83元
# --------------------Split Line--------------------
# date:2017-08-31, 卖出创建，87.00
# date:2017-09-01, 卖出已执行，86.98
# date:2017-09-01, 本次交易毛利润：-3330.00,扣除交易费用后的净利润：-3409.95
# date:2017-09-01, 交易亏损： 331
# date:2017-09-26, 总资产价格：94613.69元
# --------------------Split Line--------------------
# date:2017-09-26, 买入创建，88.08
# date:2017-09-27, 买入已执行，87.91
# date:2017-11-14, 总资产价格：105104.13元
# --------------------Split Line--------------------
# date:2017-11-14, 卖出创建，99.61
# date:2017-11-15, 卖出已执行，99.80
# date:2017-11-15, 本次交易毛利润：10701.00,扣除交易费用后的净利润：10616.53
# date:2017-11-15, 交易获利： 332
# date:2017-12-14, 总资产价格：105230.22元
# --------------------Split Line--------------------
# date:2017-12-14, 买入创建，99.34
# date:2017-12-15, 买入已执行，99.50
# date:2018-01-29, 总资产价格：104942.44元
# --------------------Split Line--------------------
# date:2018-01-29, 卖出创建，99.23
# date:2018-01-30, 卖出已执行，98.60
# date:2018-01-30, 本次交易毛利润：-810.00,扣除交易费用后的净利润：-899.15
# date:2018-01-30, 交易亏损： 333
# date:2018-03-06, 总资产价格：104331.07元
# --------------------Split Line--------------------
# date:2018-03-06, 买入创建，98.66
# date:2018-03-07, 买入已执行，98.65
# date:2018-04-02, 总资产价格：101676.68元
# --------------------Split Line--------------------
# date:2018-04-02, 卖出创建，95.75
# date:2018-04-03, 卖出已执行，95.60
# date:2018-04-03, 本次交易毛利润：-2745.00,扣除交易费用后的净利润：-2832.41
# date:2018-04-03, 交易亏损： 334
# date:2018-05-03, 总资产价格：101498.66元
# --------------------Split Line--------------------
# date:2018-05-03, 买入创建，99.49
# date:2018-05-04, 买入已执行，99.60
# date:2018-06-04, 总资产价格：111578.84元
# --------------------Split Line--------------------
# date:2018-06-04, 卖出创建，110.85
# date:2018-06-05, 卖出已执行，110.85
# date:2018-06-05, 本次交易毛利润：10125.00,扣除交易费用后的净利润：10030.30
# date:2018-06-05, 交易获利： 335
# date:2018-06-06, 总资产价格：111528.96元
# --------------------Split Line--------------------
# date:2018-06-06, 买入创建，111.48
# date:2018-06-07, 买入已执行，111.50
# date:2018-06-07, 总资产价格：108787.78元
# --------------------Split Line--------------------
# date:2018-06-07, 卖出创建，108.51
# date:2018-06-08, 卖出已执行，108.71
# date:2018-06-08, 本次交易毛利润：-2511.00,扣除交易费用后的净利润：-2610.09
# date:2018-06-08, 交易亏损： 336
# date:2018-07-17, 总资产价格：108918.86元
# --------------------Split Line--------------------
# date:2018-07-17, 买入创建，105.83
# date:2018-07-18, 买入已执行，105.83
# date:2018-07-24, 总资产价格：104884.24元
# --------------------Split Line--------------------
# date:2018-07-24, 卖出创建，101.40
# date:2018-07-25, 卖出已执行，101.31
# date:2018-07-25, 本次交易毛利润：-4068.00,扣除交易费用后的净利润：-4161.21
# date:2018-07-25, 交易亏损： 337
# date:2019-01-15, 总资产价格：104757.65元
# --------------------Split Line--------------------
# date:2019-01-15, 买入创建，75.13
# date:2019-01-16, 买入已执行，75.64
# date:2019-03-12, 总资产价格：114468.26元
# --------------------Split Line--------------------
# date:2019-03-12, 卖出创建，83.77
# date:2019-03-13, 卖出已执行，83.20
# date:2019-03-13, 本次交易毛利润：9072.00,扣除交易费用后的净利润：8976.70
# date:2019-03-13, 交易获利： 338
# date:2019-03-19, 总资产价格：113734.34元
# --------------------Split Line--------------------
# date:2019-03-19, 买入创建，86.29
# date:2019-03-20, 买入已执行，86.20
# date:2019-03-25, 总资产价格：110320.93元
# --------------------Split Line--------------------
# date:2019-03-25, 卖出创建，83.14
# date:2019-03-26, 卖出已执行，83.14
# date:2019-03-26, 本次交易毛利润：-3366.00,扣除交易费用后的净利润：-3459.14
# date:2019-03-26, 交易亏损： 339
# date:2019-04-02, 总资产价格：110275.21元
# --------------------Split Line--------------------
# date:2019-04-02, 买入创建，86.65
# date:2019-04-03, 买入已执行，86.61
# date:2019-04-29, 总资产价格：111261.57元
# --------------------Split Line--------------------
# date:2019-04-29, 卖出创建，87.55
# date:2019-04-30, 卖出已执行，87.00
# date:2019-04-30, 本次交易毛利润：429.00,扣除交易费用后的净利润：333.51
# date:2019-04-30, 交易获利： 340
# date:2019-06-21, 总资产价格：110608.72元
# --------------------Split Line--------------------
# date:2019-06-21, 买入创建，78.95
# date:2019-06-24, 买入已执行，78.95
# date:2019-07-16, 总资产价格：111977.35元
# --------------------Split Line--------------------
# date:2019-07-16, 卖出创建，80.13
# date:2019-07-17, 卖出已执行，80.05
# date:2019-07-17, 本次交易毛利润：1320.00,扣除交易费用后的净利润：1224.60
# date:2019-07-17, 交易获利： 341
# date:2019-08-20, 总资产价格：111833.32元
# --------------------Split Line--------------------
# date:2019-08-20, 买入创建，78.00
# date:2019-08-21, 买入已执行，78.19
# date:2019-09-04, 总资产价格：109230.41元
# --------------------Split Line--------------------
# date:2019-09-04, 卖出创建，76.06
# date:2019-09-05, 卖出已执行，76.10
# date:2019-09-05, 本次交易毛利润：-2508.00,扣除交易费用后的净利润：-2600.57
# date:2019-09-05, 交易亏损： 342
# date:2019-09-19, 总资产价格：109232.75元
# --------------------Split Line--------------------
# date:2019-09-19, 买入创建，77.42
# date:2019-09-20, 买入已执行，77.50
# date:2019-10-09, 总资产价格：107626.25元
# --------------------Split Line--------------------
# date:2019-10-09, 卖出创建，76.20
# date:2019-10-10, 卖出已执行，76.08
# date:2019-10-10, 本次交易毛利润：-1704.00,扣除交易费用后的净利润：-1796.15
# date:2019-10-10, 交易亏损： 343
# date:2019-10-14, 总资产价格：107436.60元
# --------------------Split Line--------------------
# date:2019-10-14, 买入创建，83.68
# date:2019-10-15, 买入已执行，83.71
# date:2019-11-28, 总资产价格：114529.56元
# --------------------Split Line--------------------
# date:2019-11-28, 卖出创建，90.20
# date:2019-11-29, 卖出已执行，90.21
# date:2019-11-29, 本次交易毛利润：7150.00,扣除交易费用后的净利润：7054.34
# date:2019-11-29, 交易获利： 344
# date:2019-12-25, 总资产价格：114490.94元
# --------------------Split Line--------------------
# date:2019-12-25, 买入创建，88.54
# date:2019-12-26, 买入已执行，88.61
# date:2020-01-17, 总资产价格：112847.21元
# --------------------Split Line--------------------
# date:2020-01-17, 卖出创建，87.16
# date:2020-01-20, 卖出已执行，87.58
# date:2020-01-20, 本次交易毛利润：-1133.00,扣除交易费用后的净利润：-1229.90
# date:2020-01-20, 交易亏损： 345
# date:2020-03-26, 总资产价格：113261.04元
# --------------------Split Line--------------------
# date:2020-03-26, 买入创建，81.50
# date:2020-03-27, 买入已执行，84.94
# date:2020-05-20, 总资产价格：115070.08元
# --------------------Split Line--------------------
# date:2020-05-20, 卖出创建，86.49
# date:2020-05-21, 卖出已执行，87.00
# date:2020-05-21, 本次交易毛利润：2472.00,扣除交易费用后的净利润：2368.84
# date:2020-05-21, 交易获利： 346
# date:2020-06-03, 总资产价格：115629.88元
# --------------------Split Line--------------------
# date:2020-06-03, 买入创建，90.95
# date:2020-06-04, 买入已执行，90.94
# date:2020-06-10, 总资产价格：111883.86元
# --------------------Split Line--------------------
# date:2020-06-10, 卖出创建，87.58
# date:2020-06-11, 卖出已执行，87.05
# date:2020-06-11, 本次交易毛利润：-4279.00,扣除交易费用后的净利润：-4376.89
# date:2020-06-11, 交易亏损： 347
# date:2020-06-18, 总资产价格：111252.98元
# --------------------Split Line--------------------
# date:2020-06-18, 买入创建，89.78
# date:2020-06-19, 买入已执行，89.78
# date:2020-07-30, 总资产价格：132675.60元
# --------------------Split Line--------------------
# date:2020-07-30, 卖出创建，109.30
# date:2020-07-31, 卖出已执行，109.28
# date:2020-07-31, 本次交易毛利润：21450.00,扣除交易费用后的净利润：21340.52
# date:2020-07-31, 交易获利： 348
# date:2020-07-31, 总资产价格：132593.50元
# --------------------Split Line--------------------
# date:2020-07-31, 买入创建，109.58
# date:2020-08-03, 买入已执行，111.18
# date:2020-08-12, 总资产价格：124627.91元
# --------------------Split Line--------------------
# date:2020-08-12, 卖出创建，103.27
# date:2020-08-13, 卖出已执行，103.70
# date:2020-08-13, 本次交易毛利润：-7480.00,扣除交易费用后的净利润：-7587.44
# date:2020-08-13, 交易亏损： 349
# date:2020-08-31, 总资产价格：125006.06元
# --------------------Split Line--------------------
# date:2020-08-31, 买入创建，115.71
# date:2020-09-01, 买入已执行，116.17
# date:2020-09-10, 总资产价格：116997.78元
# --------------------Split Line--------------------
# date:2020-09-10, 卖出创建，107.33
# date:2020-09-11, 卖出已执行，107.00
# date:2020-09-11, 本次交易毛利润：-8253.00,扣除交易费用后的净利润：-8353.43
# date:2020-09-11, 交易亏损： 350
# date:2020-09-16, 总资产价格：116652.63元
# --------------------Split Line--------------------
# date:2020-09-16, 买入创建，109.22
# date:2020-09-17, 买入已执行，109.22
# date:2020-09-17, 总资产价格：113696.48元
# --------------------Split Line--------------------
# date:2020-09-17, 卖出创建，105.99
# date:2020-09-18, 卖出已执行，105.51
# date:2020-09-18, 本次交易毛利润：-3339.00,扣除交易费用后的净利润：-3435.63
# date:2020-09-18, 交易亏损： 351
# date:2020-10-16, 总资产价格：113217.00元
# --------------------Split Line--------------------
# date:2020-10-16, 买入创建，105.80
# date:2020-10-19, 买入已执行，105.90
# date:2020-10-20, 总资产价格：111567.35元
# --------------------Split Line--------------------
# date:2020-10-20, 卖出创建，104.12
# date:2020-10-21, 卖出已执行，103.90
# date:2020-10-21, 本次交易毛利润：-1800.00,扣除交易费用后的净利润：-1894.41
# date:2020-10-21, 交易亏损： 352
# date:2020-12-04, 总资产价格：111322.59元
# --------------------Split Line--------------------
# date:2020-12-04, 买入创建，101.15
# date:2020-12-07, 买入已执行，101.18
# date:2021-01-29, 总资产价格：139888.06元
# --------------------Split Line--------------------
# date:2021-01-29, 卖出创建，132.97
# date:2021-02-01, 卖出已执行，132.80
# date:2021-02-01, 本次交易毛利润：28458.00,扣除交易费用后的净利润：28352.71
# date:2021-02-01, 交易获利： 353
# date:2021-02-08, 总资产价格：139675.30元
# --------------------Split Line--------------------
# date:2021-02-08, 买入创建，148.61
# date:2021-02-09, 买入已执行，149.80
# date:2021-02-26, 总资产价格：124423.38元
# --------------------Split Line--------------------
# date:2021-02-26, 卖出创建，130.81
# date:2021-03-01, 卖出已执行，131.91
# date:2021-03-01, 本次交易毛利润：-14312.00,扣除交易费用后的净利润：-14424.68
# date:2021-03-01, 交易亏损： 354
# date:2021-03-26, 总资产价格：125250.62元
# --------------------Split Line--------------------
# date:2021-03-26, 买入创建，134.04
# date:2021-03-29, 买入已执行，129.97
# date:2021-04-02, 总资产价格：119550.63元
# --------------------Split Line--------------------
# date:2021-04-02, 卖出创建，122.91
# date:2021-04-06, 卖出已执行，122.79
# date:2021-04-06, 本次交易毛利润：-5744.00,扣除交易费用后的净利润：-5845.10
# date:2021-04-06, 交易亏损： 355
# date:2021-05-19, 总资产价格：119405.51元
# --------------------Split Line--------------------
# date:2021-05-19, 买入创建，112.79
# date:2021-05-20, 买入已执行，112.20
# date:2021-06-10, 总资产价格：119805.02元
# --------------------Split Line--------------------
# date:2021-06-10, 卖出创建，112.70
# date:2021-06-11, 卖出已执行，112.06
# date:2021-06-11, 本次交易毛利润：-126.00,扣除交易费用后的净利润：-226.92
# date:2021-06-11, 交易亏损： 356
# date:2021-07-01, 总资产价格：119178.60元
# --------------------Split Line--------------------
# date:2021-07-01, 买入创建，119.70
# date:2021-07-02, 买入已执行，119.85
# date:2021-07-09, 总资产价格：106538.66元
# --------------------Split Line--------------------
# date:2021-07-09, 卖出创建，104.11
# date:2021-07-12, 卖出已执行，104.99
# date:2021-07-12, 本次交易毛利润：-11888.00,扣除交易费用后的净利润：-11977.94
# date:2021-07-12, 交易亏损： 357
# date:2021-09-06, 总资产价格：107200.66元
# --------------------Split Line--------------------
# date:2021-09-06, 买入创建，94.74
# date:2021-09-07, 买入已执行，94.74
# date:2021-10-15, 总资产价格：106953.29元
# --------------------Split Line--------------------
# date:2021-10-15, 卖出创建，94.54
# date:2021-10-18, 卖出已执行，94.55
# date:2021-10-18, 本次交易毛利润：-190.00,扣除交易费用后的净利润：-284.64
# date:2021-10-18, 交易亏损： 358
# date:2021-11-19, 总资产价格：106916.02元
# --------------------Split Line--------------------
# date:2021-11-19, 买入创建，90.02
# date:2021-11-22, 买入已执行，90.00
# date:2021-11-29, 总资产价格：104821.02元
# --------------------Split Line--------------------
# date:2021-11-29, 卖出创建，87.95
# date:2021-11-30, 卖出已执行，88.16
# date:2021-11-30, 本次交易毛利润：-1840.00,扣除交易费用后的净利润：-1929.08
# date:2021-11-30, 交易亏损： 359
# date:2021-12-08, 总资产价格：104986.94元
# --------------------Split Line--------------------
# date:2021-12-08, 买入创建，90.99
# date:2021-12-09, 买入已执行，91.00
# date:2022-01-20, 总资产价格：113491.44元
# --------------------Split Line--------------------
# date:2022-01-20, 卖出创建，99.55
# date:2022-01-21, 卖出已执行，99.10
# date:2022-01-21, 本次交易毛利润：8100.00,扣除交易费用后的净利润：8004.95
# date:2022-01-21, 交易获利： 360
# date:2022-03-31, 总资产价格：112991.89元
# --------------------Split Line--------------------
# date:2022-03-31, 买入创建，81.82
# date:2022-04-01, 买入已执行，80.90
# date:2022-04-11, 总资产价格：109235.35元
# --------------------Split Line--------------------
# date:2022-04-11, 卖出创建，77.81
# date:2022-04-12, 卖出已执行，77.78
# date:2022-04-12, 本次交易毛利润：-3744.00,扣除交易费用后的净利润：-3839.21
# date:2022-04-12, 交易亏损： 361
# date:2022-06-16, 总资产价格：109152.68元
# --------------------Split Line--------------------
# date:2022-06-16, 买入创建，57.89
# date:2022-06-17, 买入已执行，57.64
# date:2022-07-12, 总资产价格：107298.57元
# --------------------Split Line--------------------
# date:2022-07-12, 卖出创建，56.51
# date:2022-07-13, 卖出已执行，56.50
# date:2022-07-13, 本次交易毛利润：-1824.00,扣除交易费用后的净利润：-1915.31
# date:2022-07-13, 交易亏损： 362
# date:2022-09-16, 总资产价格：107237.37元
# --------------------Split Line--------------------
# date:2022-09-16, 买入创建，52.16
# date:2022-09-19, 买入已执行，52.06
# date:2022-09-22, 总资产价格：105822.51元
# --------------------Split Line--------------------
# date:2022-09-22, 卖出创建，51.30
# date:2022-09-23, 卖出已执行，51.30
# date:2022-09-23, 本次交易毛利润：-1368.00,扣除交易费用后的净利润：-1461.02
# date:2022-09-23, 交易亏损： 363
# date:2022-10-10, 总资产价格：105776.34元
# --------------------Split Line--------------------
# date:2022-10-10, 买入创建，51.80
# date:2022-10-11, 买入已执行，51.77
# date:2022-10-13, 总资产价格：106863.75元
# --------------------Split Line--------------------
# date:2022-10-13, 卖出创建，52.40
# date:2022-10-14, 卖出已执行，52.45
# date:2022-10-14, 本次交易毛利润：1224.00,扣除交易费用后的净利润：1130.20
# date:2022-10-14, 交易获利： 364
# date:2022-10-14, 总资产价格：106906.54元
# --------------------Split Line--------------------
# date:2022-10-14, 买入创建，53.95
# date:2022-10-17, 买入已执行，54.10
# 初始资金: 100000.0
# 回测期间：20121120:20221120
# 总资金: 113609.56
# 净收益: 13609.56
