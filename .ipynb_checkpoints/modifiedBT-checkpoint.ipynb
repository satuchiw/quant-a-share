# %%
import import_ipynb
from readdata import *
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
import backtrader as bt

# ========================
# Helper Functions
# ========================
def import_data_from_csv(file_path):
    columns = ['date','open','close','high', 'low', 'volume']
    data = pd.read_csv(file_path, usecols=columns, parse_dates=True, index_col='date')
    return data.sort_index()

# ========================
# Strategy Class
# ========================
class Strategy_MA(bt.Strategy):
    params = dict(
        ma5_period=5,
        ma20_period=20,
        risk_pct=0.9,
        use_stop_loss=False,
        stop_loss_pct=0.05,
        _end_date=None  # Add this line to fix the error
    )


    def __init__(self):
        self.order = None
        self.buyprice = None
        self.buycomm = None

        self.ma5 = bt.indicators.SMA(self.data.close, period=self.p.ma5_period)
        self.ma20 = bt.indicators.SMA(self.data.close, period=self.p.ma20_period)

    def log(self, txt, dt=None):
        dt = dt or self.datas[0].datetime.date(0)
        print(f'date:{dt.isoformat()}, {txt}')

    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            return

        if order.status in [order.Completed]:
            if order.isbuy():
                self.log(f'BUY EXECUTED, Price: {order.executed.price:.2f}')
            elif order.issell():
                self.log(f'SELL EXECUTED, Price: {order.executed.price:.2f}')
            self.bar_executed = len(self)
        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('Order Canceled/Margin/Rejected')

        self.order = None

    def notify_trade(self, trade):
        if not trade.isclosed:
            return
        self.log(f'Gross PnL: {trade.pnl:.2f}, Net PnL: {trade.pnlcomm:.2f}')

    def check_buy_signal(self):
        return self.ma5[0] > self.ma20[0] and self.ma5[-1] < self.ma20[-1]

    def check_sell_signal(self):
        return self.ma5[0] < self.ma20[0] and self.ma5[-1] > self.ma20[-1]

    def next(self):
        if self.order:
            return

        if self.datas[0].datetime.date(0) == self.params._end_date:
            return

        total_value = self.broker.getvalue()
        close_price = self.data.close[0]

        if self.position:
            if self.check_sell_signal():
                self.log(f"Total Value: {total_value:.2f}")
                self.log(f"SELL SIGNAL @ {close_price:.2f}")
                self.order = self.close()
        else:
            if self.check_buy_signal():
                invest_amt = total_value * self.p.risk_pct
                size = int(invest_amt / close_price // 100 * 100)
                self.log(f"Total Value: {total_value:.2f}")
                self.log(f"BUY SIGNAL @ {close_price:.2f}, Size: {size}")
                self.order = self.buy(size=size)
                if self.p.use_stop_loss:
                    sl_price = close_price * (1 - self.p.stop_loss_pct)
                    self.sell(exectype=bt.Order.Stop, price=sl_price, size=size)

# ========================
# Run Backtest
# ========================
def run_backtest(strategy, data, startcash, start, end):
    cerebro = bt.Cerebro()
    cerebro.addstrategy(strategy, _end_date=end)
    cerebro.broker.setcash(startcash)
    cerebro.broker.setcommission(commission=0.0005)
    
    datafeed = bt.feeds.PandasData(dataname=data, fromdate=start, todate=end)
    cerebro.adddata(datafeed)

    cerebro.addanalyzer(bt.analyzers.TradeAnalyzer, _name='ta')
    cerebro.addanalyzer(bt.analyzers.AnnualReturn, _name='ar')
    cerebro.addanalyzer(bt.analyzers.DrawDown, _name='dd')
    cerebro.addanalyzer(bt.analyzers.SharpeRatio, _name='sharpe')

    cerebro.addobserver(bt.observers.BuySell)
    cerebro.addobserver(bt.observers.Value)
    cerebro.addobserver(bt.observers.DrawDown)

    results = cerebro.run()
    return cerebro, results

# ========================
# Analysis Helpers
# ========================
def evaluate_results(cerebro, results, startcash):
    portvalue = cerebro.broker.getvalue()
    pnl = portvalue - startcash
    print(f'Final Portfolio Value: {portvalue:.2f}')
    print(f'Net PnL: {pnl:.2f}')

def analyze_backtest(cerebro, results):
    strat = results[0]
    ta = strat.analyzers.ta.get_analysis()
    dd = strat.analyzers.dd.get_analysis()
    sharpe = strat.analyzers.sharpe.get_analysis()
    ar = strat.analyzers.ar.get_analysis()

    print("\n===== Trade Stats =====")
    print(f"Total Trades: {ta.total.closed}")
    print(f"Wins: {ta.won.total} ({ta.won.total/ta.total.closed*100:.2f}%)")
    print(f"Losses: {ta.lost.total} ({ta.lost.total/ta.total.closed*100:.2f}%)")

    print("\n===== Risk Metrics =====")
    print(f"Max Drawdown: {dd.max.drawdown:.2f}%")
    print(f"Longest Drawdown: {dd.max.len} days")
    print(f"Sharpe Ratio: {sharpe['sharperatio']:.2f}")

    print("\n===== Annual Returns =====")
    for year, ret in ar.items():
        print(f"{year}: {ret*100:.2f}%")

    cerebro.plot(style='candlestick')

# ========================
# Run Main
# ========================
if __name__ == '__main__':
    start = datetime.strptime('2012-11-20', '%Y-%m-%d')
    end = datetime.strptime('2022-11-20', '%Y-%m-%d')
    startcash = 100000.0
    code = "sz.000538"
    freq = 'd'

    login_baostock()
    rs1 = marketinfo(code, str(start.date()), str(end.date()), frequency=freq)
    rs = get_result(rs1)
    logout_baostock()

    data = rs[['date', 'open', 'close', 'high', 'low', 'volume']].copy()
    numeric_columns = ['open', 'close', 'high', 'low', 'volume']
    data[numeric_columns] = data[numeric_columns].astype(float)
    data['date'] = pd.to_datetime(data['date'])
    data.set_index('date', inplace=True)

    cerebro, results = run_backtest(Strategy_MA, data, startcash, start, end)
    evaluate_results(cerebro, results, startcash)
    analyze_backtest(cerebro, results)
# Out:
# login success!
# login respond error_code:0
# login respond error_msg:success
# query_history_k_data_plus respond error_code:0
# query_history_k_data_plus respond error_msg:success
# logout success!
# date:2012-12-20, Total Value: 100000.00
# date:2012-12-20, BUY SIGNAL @ 63.60, Size: 1400
# date:2012-12-21, BUY EXECUTED, Price: 63.65
# date:2013-03-01, Total Value: 118561.45
# date:2013-03-01, SELL SIGNAL @ 76.94
# date:2013-03-04, SELL EXECUTED, Price: 77.90
# date:2013-03-04, Gross PnL: 19950.00, Net PnL: 19850.92
# date:2013-03-05, Total Value: 119850.92
# date:2013-03-05, BUY SIGNAL @ 79.76, Size: 1300
# date:2013-03-06, BUY EXECUTED, Price: 79.75
# date:2013-03-13, Total Value: 113910.08
# date:2013-03-13, SELL SIGNAL @ 75.22
# date:2013-03-14, SELL EXECUTED, Price: 74.55
# date:2013-03-14, Gross PnL: -6760.00, Net PnL: -6860.30
# date:2013-03-19, Total Value: 112990.62
# date:2013-03-19, BUY SIGNAL @ 78.52, Size: 1200
# date:2013-03-20, BUY EXECUTED, Price: 78.53
# date:2013-04-10, Total Value: 116507.50
# date:2013-04-10, SELL SIGNAL @ 81.50
# date:2013-04-11, SELL EXECUTED, Price: 81.50
# date:2013-04-11, Gross PnL: 3564.00, Net PnL: 3467.98
# date:2013-04-19, Total Value: 116458.60
# date:2013-04-19, BUY SIGNAL @ 85.45, Size: 1200
# date:2013-04-22, BUY EXECUTED, Price: 88.50
# date:2013-05-21, Total Value: 112205.50
# date:2014-04-14, BUY EXECUTED, Price: 87.78
# date:2014-04-29, Total Value: 93073.96
# date:2014-04-29, SELL SIGNAL @ 82.66
# date:2014-04-30, SELL EXECUTED, Price: 86.00
# date:2014-04-30, Gross PnL: -1780.00, Net PnL: -1866.89
# date:2014-05-07, Total Value: 96370.96
# date:2014-05-07, BUY SIGNAL @ 87.05, Size: 900
# date:2014-05-08, BUY EXECUTED, Price: 86.85
# date:2014-05-22, Total Value: 96601.87
# date:2014-05-22, SELL SIGNAL @ 87.15
# date:2014-05-23, SELL EXECUTED, Price: 87.01
# date:2014-05-23, Gross PnL: 144.00, Net PnL: 65.76
# date:2014-05-27, Total Value: 96436.72
# date:2014-05-27, BUY SIGNAL @ 87.32, Size: 900
# date:2014-05-28, BUY EXECUTED, Price: 57.53
# date:2014-05-28, Total Value: 96797.83
# date:2014-05-28, SELL SIGNAL @ 57.96
# date:2014-05-29, SELL EXECUTED, Price: 58.25
# date:2014-05-29, Gross PnL: 648.00, Net PnL: 595.90
# date:2014-07-22, Total Value: 97032.62
# date:2014-07-22, BUY SIGNAL @ 51.91, Size: 1600
# date:2014-07-23, BUY EXECUTED, Price: 51.88
# date:2014-08-15, Total Value: 99711.11
# date:2014-08-15, SELL SIGNAL @ 53.58
# date:2014-08-18, SELL EXECUTED, Price: 53.55
# date:2014-08-18, Gross PnL: 2672.00, Net PnL: 2587.66
# date:2014-09-10, Total Value: 99620.27
# date:2014-09-10, BUY SIGNAL @ 51.80, Size: 1700
# date:2014-09-11, BUY EXECUTED, Price: 51.80
# date:2014-09-16, Total Value: 97281.24
# date:2014-09-16, SELL SIGNAL @ 50.45
# date:2014-09-17, SELL EXECUTED, Price: 50.60
# date:2014-09-17, Gross PnL: -2040.00, Net PnL: -2127.04
# date:2014-09-23, Total Value: 97493.23
# date:2014-09-23, BUY SIGNAL @ 51.45, Size: 1700
# date:2014-09-24, BUY EXECUTED, Price: 51.31
# date:2014-09-30, Total Value: 97381.62
# date:2014-09-30, SELL SIGNAL @ 51.27
# date:2014-10-08, SELL EXECUTED, Price: 51.40
# date:2014-10-08, Gross PnL: 153.00, Net PnL: 65.70
# date:2014-10-08, Total Value: 97558.93
# date:2014-10-08, BUY SIGNAL @ 56.40, Size: 1500
# date:2014-10-09, BUY EXECUTED, Price: 57.00
# date:2014-10-27, Total Value: 91696.18
# date:2014-10-27, SELL SIGNAL @ 53.12
# date:2014-10-28, SELL EXECUTED, Price: 53.30
# date:2014-10-28, Gross PnL: -5550.00, Net PnL: -5632.73
# date:2014-11-14, Total Value: 91926.20
# date:2014-11-14, BUY SIGNAL @ 55.16, Size: 1400
# date:2014-11-17, BUY EXECUTED, Price: 55.55
# date:2014-12-23, Total Value: 96437.32
# date:2014-12-23, SELL SIGNAL @ 58.80
# date:2014-12-24, SELL EXECUTED, Price: 58.80
# date:2014-12-24, Gross PnL: 4550.00, Net PnL: 4469.95
# date:2014-12-31, Total Value: 96396.16
# date:2018-06-05, SELL EXECUTED, Price: 110.85
# date:2018-06-05, Gross PnL: 10125.00, Net PnL: 10030.30
# date:2018-06-06, Total Value: 111528.96
# date:2018-06-06, BUY SIGNAL @ 111.48, Size: 900
# date:2018-06-07, BUY EXECUTED, Price: 111.50
# date:2018-06-07, Total Value: 108787.78
# date:2018-06-07, SELL SIGNAL @ 108.51
# date:2018-06-08, SELL EXECUTED, Price: 108.71
# date:2018-06-08, Gross PnL: -2511.00, Net PnL: -2610.09
# date:2018-07-17, Total Value: 108918.86
# date:2018-07-17, BUY SIGNAL @ 105.83, Size: 900
# date:2018-07-18, BUY EXECUTED, Price: 105.83
# date:2018-07-24, Total Value: 104884.24
# date:2018-07-24, SELL SIGNAL @ 101.40
# date:2018-07-25, SELL EXECUTED, Price: 101.31
# date:2018-07-25, Gross PnL: -4068.00, Net PnL: -4161.21
# date:2019-01-15, Total Value: 104757.65
# date:2019-01-15, BUY SIGNAL @ 75.13, Size: 1200
# date:2019-01-16, BUY EXECUTED, Price: 75.64
# date:2019-03-12, Total Value: 114468.26
# date:2019-03-12, SELL SIGNAL @ 83.77
# date:2019-03-13, SELL EXECUTED, Price: 83.20
# date:2019-03-13, Gross PnL: 9072.00, Net PnL: 8976.70
# date:2019-03-19, Total Value: 113734.34
# date:2019-03-19, BUY SIGNAL @ 86.29, Size: 1100
# date:2019-03-20, BUY EXECUTED, Price: 86.20
# date:2019-03-25, Total Value: 110320.93
# date:2019-03-25, SELL SIGNAL @ 83.14
# date:2019-03-26, SELL EXECUTED, Price: 83.14
# date:2019-03-26, Gross PnL: -3366.00, Net PnL: -3459.14
# date:2019-04-02, Total Value: 110275.21
# date:2019-04-02, BUY SIGNAL @ 86.65, Size: 1100
# date:2019-04-03, BUY EXECUTED, Price: 86.61
# date:2019-04-29, Total Value: 111261.57
# date:2019-04-29, SELL SIGNAL @ 87.55
# date:2019-04-30, SELL EXECUTED, Price: 87.00
# date:2019-04-30, Gross PnL: 429.00, Net PnL: 333.51
# date:2019-06-21, Total Value: 110608.72
# date:2019-06-21, BUY SIGNAL @ 78.95, Size: 1200
# date:2019-06-24, BUY EXECUTED, Price: 78.95
# date:2019-07-16, Total Value: 111977.35
# date:2019-07-16, SELL SIGNAL @ 80.13
# date:2019-07-17, SELL EXECUTED, Price: 80.05
# date:2019-07-17, Gross PnL: 1320.00, Net PnL: 1224.60
# date:2019-08-20, Total Value: 111833.32
# date:2019-08-20, BUY SIGNAL @ 78.00, Size: 1200
# date:2019-08-21, BUY EXECUTED, Price: 78.19
# date:2019-09-04, Total Value: 109230.41
# date:2019-09-04, SELL SIGNAL @ 76.06
# date:2019-09-05, SELL EXECUTED, Price: 76.10
# date:2019-09-05, Gross PnL: -2508.00, Net PnL: -2600.57
# date:2019-09-19, Total Value: 109232.75
# date:2019-09-19, BUY SIGNAL @ 77.42, Size: 1200
# date:2019-09-20, BUY EXECUTED, Price: 77.50
# date:2019-10-09, Total Value: 107626.25
# date:2019-10-09, SELL SIGNAL @ 76.20
# date:2019-10-10, SELL EXECUTED, Price: 76.08
# date:2019-10-10, Gross PnL: -1704.00, Net PnL: -1796.15
# date:2019-10-14, Total Value: 107436.60
# date:2019-10-14, BUY SIGNAL @ 83.68, Size: 1100
# date:2019-10-15, BUY EXECUTED, Price: 83.71
# date:2019-11-28, Total Value: 114529.56
# date:2019-11-28, SELL SIGNAL @ 90.20
# date:2019-11-29, SELL EXECUTED, Price: 90.21
# date:2019-11-29, Gross PnL: 7150.00, Net PnL: 7054.34
# date:2019-12-25, Total Value: 114490.94
# date:2019-12-25, BUY SIGNAL @ 88.54, Size: 1100
# date:2019-12-26, BUY EXECUTED, Price: 88.61
# date:2020-01-17, Total Value: 112847.21
# date:2020-01-17, SELL SIGNAL @ 87.16
# date:2020-01-20, SELL EXECUTED, Price: 87.58
# date:2020-01-20, Gross PnL: -1133.00, Net PnL: -1229.90
# date:2020-03-26, Total Value: 113261.04
# date:2020-03-26, BUY SIGNAL @ 81.50, Size: 1200
# date:2020-03-27, BUY EXECUTED, Price: 84.94
# date:2020-05-20, Total Value: 115070.08
# date:2020-05-20, SELL SIGNAL @ 86.49
# date:2020-05-21, SELL EXECUTED, Price: 87.00
# date:2020-05-21, Gross PnL: 2472.00, Net PnL: 2368.84
# date:2020-06-03, Total Value: 115629.88
# date:2020-06-03, BUY SIGNAL @ 90.95, Size: 1100
# date:2020-06-04, BUY EXECUTED, Price: 90.94
# date:2020-06-10, Total Value: 111883.86
# date:2020-06-10, SELL SIGNAL @ 87.58
# date:2020-06-11, SELL EXECUTED, Price: 87.05
# date:2020-06-11, Gross PnL: -4279.00, Net PnL: -4376.89
# date:2020-06-18, Total Value: 111252.98
# date:2020-06-18, BUY SIGNAL @ 89.78, Size: 1100
# date:2020-06-19, BUY EXECUTED, Price: 89.78
# date:2020-07-30, Total Value: 132675.60
# date:2020-07-30, SELL SIGNAL @ 109.30
# date:2020-07-31, SELL EXECUTED, Price: 109.28
# date:2020-07-31, Gross PnL: 21450.00, Net PnL: 21340.52
# date:2020-07-31, Total Value: 132593.50
# date:2020-07-31, BUY SIGNAL @ 109.58, Size: 1000
# date:2020-08-03, BUY EXECUTED, Price: 111.18
# date:2020-08-12, Total Value: 124627.91
# date:2020-08-12, SELL SIGNAL @ 103.27
# date:2020-08-13, SELL EXECUTED, Price: 103.70
# date:2020-08-13, Gross PnL: -7480.00, Net PnL: -7587.44
# date:2020-08-31, Total Value: 125006.06
# date:2020-08-31, BUY SIGNAL @ 115.71, Size: 900
# date:2020-09-01, BUY EXECUTED, Price: 116.17
# date:2020-09-10, Total Value: 116997.78
# date:2020-09-10, SELL SIGNAL @ 107.33
# date:2020-09-11, SELL EXECUTED, Price: 107.00
# date:2020-09-11, Gross PnL: -8253.00, Net PnL: -8353.43
# date:2020-09-16, Total Value: 116652.63
# date:2020-09-16, BUY SIGNAL @ 109.22, Size: 900
# date:2020-09-17, BUY EXECUTED, Price: 109.22
# date:2020-09-17, Total Value: 113696.48
# date:2020-09-17, SELL SIGNAL @ 105.99
# date:2020-09-18, SELL EXECUTED, Price: 105.51
# date:2020-09-18, Gross PnL: -3339.00, Net PnL: -3435.63
# date:2020-10-16, Total Value: 113217.00
# date:2020-10-16, BUY SIGNAL @ 105.80, Size: 900
# date:2020-10-19, BUY EXECUTED, Price: 105.90
# date:2020-10-20, Total Value: 111567.35
# date:2020-10-20, SELL SIGNAL @ 104.12
# date:2020-10-21, SELL EXECUTED, Price: 103.90
# date:2020-10-21, Gross PnL: -1800.00, Net PnL: -1894.41
# date:2020-12-04, Total Value: 111322.59
# date:2020-12-04, BUY SIGNAL @ 101.15, Size: 900
# date:2020-12-07, BUY EXECUTED, Price: 101.18
# date:2021-01-29, Total Value: 139888.06
# date:2021-01-29, SELL SIGNAL @ 132.97
# date:2021-02-01, SELL EXECUTED, Price: 132.80
# date:2021-02-01, Gross PnL: 28458.00, Net PnL: 28352.71
# date:2021-02-08, Total Value: 139675.30
# date:2021-02-08, BUY SIGNAL @ 148.61, Size: 800
# date:2021-02-09, BUY EXECUTED, Price: 149.80
# date:2021-02-26, Total Value: 124423.38
# date:2021-02-26, SELL SIGNAL @ 130.81
# date:2021-03-01, SELL EXECUTED, Price: 131.91
# date:2021-03-01, Gross PnL: -14312.00, Net PnL: -14424.68
# date:2021-03-26, Total Value: 125250.62
# date:2021-03-26, BUY SIGNAL @ 134.04, Size: 800
# date:2021-03-29, BUY EXECUTED, Price: 129.97
# date:2021-04-02, Total Value: 119550.63
# date:2021-04-02, SELL SIGNAL @ 122.91
# date:2021-04-06, SELL EXECUTED, Price: 122.79
# date:2021-04-06, Gross PnL: -5744.00, Net PnL: -5845.10
# date:2021-05-19, Total Value: 119405.51
# date:2021-05-19, BUY SIGNAL @ 112.79, Size: 900
# date:2021-05-20, BUY EXECUTED, Price: 112.20
# date:2021-06-10, Total Value: 119805.02
# date:2021-06-10, SELL SIGNAL @ 112.70
# date:2021-06-11, SELL EXECUTED, Price: 112.06
# date:2021-06-11, Gross PnL: -126.00, Net PnL: -226.92
# date:2021-07-01, Total Value: 119178.60
# date:2021-07-01, BUY SIGNAL @ 119.70, Size: 800
# date:2021-07-02, BUY EXECUTED, Price: 119.85
# date:2021-07-09, Total Value: 106538.66
# date:2021-07-09, SELL SIGNAL @ 104.11
# date:2021-07-12, SELL EXECUTED, Price: 104.99
# date:2021-07-12, Gross PnL: -11888.00, Net PnL: -11977.94
# date:2021-09-06, Total Value: 107200.66
# date:2021-09-06, BUY SIGNAL @ 94.74, Size: 1000
# date:2021-09-07, BUY EXECUTED, Price: 94.74
# date:2021-10-15, Total Value: 106953.29
# date:2021-10-15, SELL SIGNAL @ 94.54
# date:2021-10-18, SELL EXECUTED, Price: 94.55
# date:2021-10-18, Gross PnL: -190.00, Net PnL: -284.64
# date:2021-11-19, Total Value: 106916.02
# date:2021-11-19, BUY SIGNAL @ 90.02, Size: 1000
# date:2021-11-22, BUY EXECUTED, Price: 90.00
# date:2021-11-29, Total Value: 104821.02
# date:2021-11-29, SELL SIGNAL @ 87.95
# date:2021-11-30, SELL EXECUTED, Price: 88.16
# date:2021-11-30, Gross PnL: -1840.00, Net PnL: -1929.08
# date:2021-12-08, Total Value: 104986.94
# date:2021-12-08, BUY SIGNAL @ 90.99, Size: 1000
# date:2021-12-09, BUY EXECUTED, Price: 91.00
# date:2022-01-20, Total Value: 113491.44
# date:2022-01-20, SELL SIGNAL @ 99.55
# date:2022-01-21, SELL EXECUTED, Price: 99.10
# date:2022-01-21, Gross PnL: 8100.00, Net PnL: 8004.95
# date:2022-03-31, Total Value: 112991.89
# date:2022-03-31, BUY SIGNAL @ 81.82, Size: 1200
# date:2022-04-01, BUY EXECUTED, Price: 80.90
# date:2022-04-11, Total Value: 109235.35
# date:2022-04-11, SELL SIGNAL @ 77.81
# date:2022-04-12, SELL EXECUTED, Price: 77.78
# date:2022-04-12, Gross PnL: -3744.00, Net PnL: -3839.21
# date:2022-06-16, Total Value: 109152.68
# date:2022-06-16, BUY SIGNAL @ 57.89, Size: 1600
# date:2022-06-17, BUY EXECUTED, Price: 57.64
# date:2022-07-12, Total Value: 107298.57
# date:2022-07-12, SELL SIGNAL @ 56.51
# date:2022-07-13, SELL EXECUTED, Price: 56.50
# date:2022-07-13, Gross PnL: -1824.00, Net PnL: -1915.31
# date:2022-09-16, Total Value: 107237.37
# date:2022-09-16, BUY SIGNAL @ 52.16, Size: 1800
# date:2022-09-19, BUY EXECUTED, Price: 52.06
# date:2022-09-22, Total Value: 105822.51
# date:2022-09-22, SELL SIGNAL @ 51.30
# date:2022-09-23, SELL EXECUTED, Price: 51.30
# date:2022-09-23, Gross PnL: -1368.00, Net PnL: -1461.02
# date:2022-10-10, Total Value: 105776.34
# date:2022-10-10, BUY SIGNAL @ 51.80, Size: 1800
# date:2022-10-11, BUY EXECUTED, Price: 51.77
# date:2022-10-13, Total Value: 106863.75
# date:2022-10-13, SELL SIGNAL @ 52.40
# date:2022-10-14, SELL EXECUTED, Price: 52.45
# date:2022-10-14, Gross PnL: 1224.00, Net PnL: 1130.20
# date:2022-10-14, Total Value: 106906.54
# date:2022-10-14, BUY SIGNAL @ 53.95, Size: 1700
# date:2022-10-17, BUY EXECUTED, Price: 54.10
# Final Portfolio Value: 113609.56
# Net PnL: 13609.56
#
# ===== Trade Stats =====
# Total Trades: 72
# Wins: 25 (34.72%)
# Losses: 47 (65.28%)
#
# ===== Risk Metrics =====
# Max Drawdown: 30.68%
# Longest Drawdown: 1224 days
# Sharpe Ratio: 0.06
#
# ===== Annual Returns =====
# 2012: 6.05%
# 2013: 2.45%
# 2014: -11.27%
# 2015: 7.84%
# 2016: -6.22%
# 2017: 10.02%
# 2018: -2.32%
# 2019: 10.11%
# 2020: 6.16%
# 2021: -3.16%
# 2022: -4.20%
# <div id='30eb66aa-408d-4a3c-8f7e-ade32416e609'></div>
